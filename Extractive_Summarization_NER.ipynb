# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoaibSheriff/NLP/blob/master/Project/Extractive_Summarization_NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import string
import numpy as np
import matplotlib.pyplot as plt
from nltk import pos_tag
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus.reader.wordnet import NOUN, VERB, ADJ, ADV
from nltk.corpus import brown, stopwords
from nltk.cluster.util import cosine_distance
from operator import itemgetter
from pprint import pprint
# %matplotlib
# Out:
# Using matplotlib backend: agg

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from pprint import pprint
nlp = en_core_web_sm.load()

# %%
import zipfile
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import nltk
nltk.download('brown')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
class TextCleaner():
    
    def __init__(self):
        self.stop_words = set(stopwords.words("english"))
        self.punctuations = set(string.punctuation)
        self.pos_tags = {
                NOUN: ['NN', 'NNS', 'NNP', 'NNPS', 'PRP', 'PRP$', 'WP', 'WP$'],
                VERB: ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'],
                ADJ: ['JJ', 'JJR', 'JJS'],
                ADV: ['RB', 'RBR', 'RBS', 'WRB']
        }


    def _remove_stop_words(self, words):
        return [w for w in words if w not in self.stop_words]
     
    
    def _remove_regex(self):
        self.input_sent = " ".join([w.lower() for w in self.input_sent])
        self.input_sent = re.sub(r"i'm", "i am", self.input_sent)
        self.input_sent = re.sub(r"he's", "he is", self.input_sent)
        self.input_sent = re.sub(r"she's", "she is", self.input_sent)
        self.input_sent = re.sub(r"that's", "that is", self.input_sent)
        self.input_sent = re.sub(r"what's", "what is", self.input_sent)
        self.input_sent = re.sub(r"where's", "where is", self.input_sent)
        self.input_sent = re.sub(r"\'ll", " will", self.input_sent)
        self.input_sent = re.sub(r"\'ve", " have", self.input_sent)
        self.input_sent = re.sub(r"\'re", " are", self.input_sent)
        self.input_sent = re.sub(r"\'d", " would", self.input_sent)
        self.input_sent = re.sub(r"won't", "will not", self.input_sent)
        self.input_sent = re.sub(r"can't", "cannot", self.input_sent)
        self.input_sent = re.sub(r"don't", "do not", self.input_sent)
        patterns = re.finditer("#[\w]*", self.input_sent)
        for pattern in patterns:
            self.input_sent = re.sub(pattern.group().strip(), "", self.input_sent)
        self.input_sent = "".join(ch for ch in self.input_sent if ch not in self.punctuations)
    
    
    def _tokenize(self):
        return word_tokenize(self.input_sent)
    
    
    def _process_content_for_pos(self, words):
        tagged_words = pos_tag(words)
        pos_words = []
        for word in tagged_words:
            flag = False
            for key, value in self.pos_tags.items():
                if word[1] in value:
                    pos_words.append((word[0], key))
                    flag = True
                    break
            if not flag:
                pos_words.append((word[0], NOUN))
        return pos_words
       
                 
    def _remove_noise(self):
        self._remove_regex()
        words = self._tokenize()
        noise_free_words = self._remove_stop_words(words)
        return noise_free_words
    
    
    def _normalize_text(self, words):
        lem = WordNetLemmatizer()
        pos_words = self._process_content_for_pos(words)
        normalized_words = [lem.lemmatize(w, pos=p) for w, p in pos_words]
        return normalized_words
    
    
    def clean_up(self, input_sent):
        self.input_sent = input_sent
        cleaned_words = self._remove_noise()
        cleaned_words = self._normalize_text(cleaned_words)
        return cleaned_words

# %%
def pagerank(M, eps=1.0e-8, d=0.85):
    N = M.shape[1]
    v = np.random.rand(N, 1)
    v = v / np.linalg.norm(v, 1)
    last_v = np.ones((N, 1), dtype=np.float32) * np.inf
    M_hat = (d * M) + (((1 - d) / N) * np.ones((N, N), dtype=np.float32))
    
    while np.linalg.norm(v - last_v, 2) > eps:
        last_v = v
        v = np.matmul(M_hat, v)
    return v

# %%
def sentence_similarity(sent1, sent2):
    text_cleaner = TextCleaner()
    
    sent1 = text_cleaner.clean_up(sent1)
    sent2 = text_cleaner.clean_up(sent2)
    
    all_words = list(set(sent1 + sent2))
    
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
    
    for w in sent1:
        vector1[all_words.index(w)] += 1
    
    for w in sent2:
        vector2[all_words.index(w)] += 1

    
    return 1 - cosine_distance(vector1, vector2)

# %%
def build_similarity_matrix(sentences):
    S = np.zeros((len(sentences), len(sentences)))
    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i == j:
                continue
            else:
                S[i][j] = sentence_similarity(sentences[i], sentences[j])
    
    for i in range(len(S)):
        S[i] /= S[i].sum()
    return S

# %%
RATIO = 0.6

def get_summary(sentences):
  SUMMARY_SIZE = int(len(sentences) * RATIO)
  # print(SUMMARY_SIZE)
  S = build_similarity_matrix(sentences)
  sentence_ranks = pagerank(S)
  ranked_sentence_indexes = [(item[0], item[1][0]) for item in sorted(enumerate(sentence_ranks), key=lambda item: -item[1])]
  selected_sentences = sorted(ranked_sentence_indexes[:SUMMARY_SIZE], key = lambda item: item[0])
  summary = [sentences[item[0]] for item in selected_sentences]
  return summary, [item[1] for item in selected_sentences]

# %%
# i = 60

# %%
# stories_d = '/content/drive/My Drive/CSE 538/Project/af8xtr/'
# !rm -rf stories_d
# !mkdir stories_d

def add_entity_weights(sentence, weight, data) :
  # print(sentence)
  doc = nlp(sentence)
  entities = ([(X, X.ent_iob_, X.ent_type_) for X in doc])
  entity_list = []
  for entity in entities:
    if (len(entity[2]) > 0):
      entity_list.append(entity[0])
  for real_entity in set(entity_list): 
    if real_entity.text in data.keys():
      data[real_entity.text] = data.get(real_entity.text) + weight/len(entity_list)
    else:
      data[real_entity.text] = weight/len(entity_list)
  return data

# %%
import glob
from tqdm import tqdm
import os.path
from os import path

stories = glob.glob('/content/drive/My Drive/CSE 538/Project/b4xtr/*')
gdrive_out = '/content/drive/My Drive/CSE 538/Project/af8xtr/'

from google.colab import files

for story_path in tqdm(stories):

  file_name_af8r = gdrive_out+story_path[story_path.index('cnn'):-5]+'.story'
  file_name_af8r_imp = gdrive_out+story_path[story_path.index('cnn'):-5]+'.imp'
  if path.exists(file_name_af8r_imp):
    continue

  with open(story_path, 'r') as f:

    entitiy_to_weights = dict()

    lines = f.read().split('\n')
    # pprint(lines)
    main_lines = []
    known_summary = []
    sum_started = False
    for line in lines:
      if (line.startswith('@high')):
        sum_started = True
      if sum_started:
        known_summary.append(line)
      else:
        if (len(lines) > 0) :
          main_lines.append(line)
    main_lines = [x for x in main_lines if len(x) > 0]
    summary, weights = get_summary(main_lines)

    # pprint(summary)
    # pprint(weights)
    iii = 0
    filtered_lines = []
    for line in main_lines:
      if line in summary:
        if (iii < len(weights)):
          add_entity_weights(line, weights[iii], entitiy_to_weights)
        iii = iii + 1
        filtered_lines.append(line)
        filtered_lines.append("")

    filtered_lines.extend(known_summary)
    # print(entitiy_to_weights)
    
    with open(file_name_af8r_imp, 'w') as f_af84_imp:
      for ent in entitiy_to_weights.keys():
        f_af84_imp.write(ent + " " + str(entitiy_to_weights[ent]) + "\n")

    with open(file_name_af8r, 'w') as f_af84:
      for line in filtered_lines:
        # print(line)
        f_af84.write("%s\n" % line)
# Out:
#  72%|███████▏  | 5078/7054 [18:59<3:57:38,  7.22s/it]/usr/local/lib/python3.6/dist-packages/nltk/cluster/util.py:133: RuntimeWarning: invalid value encountered in true_divide
#   sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))
#  93%|█████████▎| 6575/7054 [2:58:20<1:23:15, 10.43s/it]

# %%
# !zip -r '/content/drive/My Drive/CSE 538/Project/af8xtr_imp.zip' '/content/drive/My Drive/CSE 538/Project/af8xtr_imp'
# Out:
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/ (stored 0%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3978.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3979.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3980.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3981.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3982.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3983.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3984.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3985.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3986.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3987.imp (deflated 44%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3988.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3989.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3990.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3991.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3992.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3993.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3994.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3995.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3996.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3997.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3998.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3999.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4000.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4001.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4002.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4003.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4004.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4005.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4006.imp (deflated 43%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4007.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4008.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4009.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4010.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4011.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4012.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4013.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4014.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4015.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4016.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4017.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4018.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4019.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4020.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4021.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4022.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4023.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4024.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4025.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4026.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4027.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4028.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4029.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4030.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4031.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4032.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4033.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4034.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4035.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4036.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4037.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4038.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4039.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4040.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4041.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4042.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4043.imp (deflated 48%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4044.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4045.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4046.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4047.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4048.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4049.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4050.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4051.imp (deflated 32%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4052.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4053.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2054.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2055.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2056.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2057.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2058.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2059.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2060.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2061.imp (deflated 70%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2062.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2063.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2064.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2065.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2066.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2067.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2068.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2069.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2070.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2071.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2072.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2073.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2074.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2075.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2076.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2077.imp (deflated 49%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2078.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2079.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2080.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2081.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2082.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2083.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2084.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2085.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2086.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2087.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2088.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2089.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2090.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2091.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2092.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2093.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2094.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2095.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2096.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2097.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2098.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2099.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2100.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2101.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2102.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2103.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2104.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2105.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2106.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2107.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2108.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2109.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2110.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2111.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2112.imp (deflated 35%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2113.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2114.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2115.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2116.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2117.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2118.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2119.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2120.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2121.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2122.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2123.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2124.imp (deflated 41%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2125.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2126.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2127.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2128.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2129.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2130.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2131.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2132.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2133.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2134.imp (deflated 47%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2135.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2136.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2137.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2138.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2139.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2140.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2141.imp (deflated 49%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2142.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2143.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2144.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2145.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2146.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2147.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2148.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2149.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2150.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2151.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2152.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2153.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2154.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2155.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2156.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2157.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2158.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2159.imp (deflated 51%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2160.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2161.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2162.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2163.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2164.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2165.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2166.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2167.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2168.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2169.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2170.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2171.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2172.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2173.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2174.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2175.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2176.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2177.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2178.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2179.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2180.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2181.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2182.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2183.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2184.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2185.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2186.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2187.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2188.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2189.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2190.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2191.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2192.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2193.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2194.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2195.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2196.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2197.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2198.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2199.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2200.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2201.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2202.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2203.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2204.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2205.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2206.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2207.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2208.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2209.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2210.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2211.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2212.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2213.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2214.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2215.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2216.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2217.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2218.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2219.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2220.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2221.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2222.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2223.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2224.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2225.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2226.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2227.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2228.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2229.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2230.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2231.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2232.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2233.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2234.imp (deflated 48%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2235.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2236.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2237.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2238.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2239.imp (deflated 45%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2240.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2241.imp (deflated 51%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2242.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2243.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2244.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2245.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2246.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2247.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2248.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2249.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2250.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2251.imp (deflated 50%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2252.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2253.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2254.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2255.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2256.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2257.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2258.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2259.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2260.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2261.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2262.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2263.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2264.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2265.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2266.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2267.imp (deflated 51%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2268.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2269.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2270.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2271.imp (deflated 72%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2272.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2273.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2274.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2275.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2276.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2277.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2278.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2279.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2280.imp (deflated 51%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2281.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2282.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2283.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2284.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2285.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2286.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2287.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2288.imp (deflated 39%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2289.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2290.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2291.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2292.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2293.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2294.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2295.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2296.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2297.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2298.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2299.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2300.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2301.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2302.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2303.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2304.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2305.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2306.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2307.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2308.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2309.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2310.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2311.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2312.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2313.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2314.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2315.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2316.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2317.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2318.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2319.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2320.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2321.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2322.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2323.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2324.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2325.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2326.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2327.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2328.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2329.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2330.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2331.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2332.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2333.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2334.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2335.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2336.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2337.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2338.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2339.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2340.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2341.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2342.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2343.imp (deflated 43%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2344.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2345.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2346.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2347.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2348.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2349.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2350.imp (deflated 48%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2351.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2352.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2353.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2354.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2355.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2356.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2357.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2358.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2359.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2360.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2361.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2362.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2363.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2364.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2365.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2366.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2367.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2368.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2369.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2370.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2371.imp (deflated 70%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2372.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2373.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2374.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2375.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2376.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2377.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2378.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2379.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2380.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2381.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2382.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2383.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2384.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2385.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2386.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2387.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2388.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2389.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2390.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2391.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2392.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2393.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2394.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2395.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2396.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2397.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2398.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2399.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2400.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2401.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2402.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2403.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2404.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2405.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2406.imp (deflated 39%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2407.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2408.imp (deflated 50%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2409.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2410.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2411.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2412.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2413.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2414.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2415.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2416.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2417.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2418.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2419.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2420.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2421.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2422.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2423.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2424.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2425.imp (deflated 48%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2426.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2427.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2428.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2429.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2430.imp (deflated 71%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2431.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2432.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2433.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2434.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2435.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2436.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2437.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2438.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2439.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2440.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2441.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2442.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2443.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2444.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2445.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2446.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2447.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2448.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2449.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2450.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2451.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2452.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2453.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2454.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2455.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2456.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2457.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2458.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2459.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2460.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2461.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2462.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2463.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2464.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2465.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2466.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2467.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2468.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2469.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2470.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2471.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2472.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2473.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2474.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2475.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2476.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2477.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2478.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2479.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2480.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2481.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2482.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2483.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2484.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2485.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2486.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2487.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2488.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2489.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2490.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2491.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2492.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2493.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2494.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2495.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2496.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2497.imp (deflated 65%)
# ...
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test933.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test934.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test935.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test936.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test937.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test938.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test939.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test940.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test941.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test942.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test943.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test944.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test945.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test946.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test947.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test948.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test949.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test950.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test951.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test952.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test953.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test954.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test955.imp (deflated 52%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test956.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test957.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test958.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test959.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test960.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test961.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test962.imp (deflated 51%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test963.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test964.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test965.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test966.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test967.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test968.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test969.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test970.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test971.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test972.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test973.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test974.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test975.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test976.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test977.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test978.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test979.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test980.imp (deflated 25%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test981.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test982.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test983.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test984.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test985.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test986.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test987.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test988.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test989.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test990.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test991.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test992.imp (deflated 51%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test993.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test994.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test995.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test996.imp (deflated 70%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test997.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test998.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test999.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1000.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1001.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1002.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1003.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1004.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1005.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1006.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1007.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1008.imp (deflated 46%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1009.imp (deflated 50%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1010.imp (deflated 43%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1011.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1012.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1013.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1014.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1015.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1016.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1017.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1018.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1019.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1020.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1021.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1022.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1023.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1024.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1025.imp (deflated 70%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1026.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1027.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1028.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1029.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1030.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1031.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1032.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1033.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1034.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1035.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1036.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1037.imp (deflated 50%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1038.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1039.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1040.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1041.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1042.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1043.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1044.imp (deflated 53%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1045.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1046.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1047.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1048.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1049.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1050.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1051.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1052.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1053.imp (deflated 46%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test0.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test1.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test2.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test3.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test4.imp (deflated 57%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test5.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test6.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test7.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test8.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test9.imp (deflated 56%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test10.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test11.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test12.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test13.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test14.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test15.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test16.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test17.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test18.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test19.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test20.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test21.imp (deflated 55%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test22.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test23.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test24.imp (deflated 67%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test25.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test26.imp (deflated 69%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test27.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test28.imp (deflated 68%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test29.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test30.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test31.imp (deflated 65%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test32.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test33.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test34.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test35.imp (deflated 59%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test36.imp (deflated 64%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test37.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test38.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test39.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test40.imp (deflated 58%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test41.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test42.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test43.imp (deflated 63%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test44.imp (deflated 42%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test45.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test46.imp (deflated 60%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test47.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test48.imp (deflated 66%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test49.imp (deflated 54%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test50.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test51.imp (deflated 62%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test52.imp (deflated 61%)
#   adding: content/drive/My Drive/CSE 538/Project/af8xtr_imp/cnn_test53.imp (deflated 62%)
